# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io

path = get_file(
    'potter.txt',
    origin='https://raw.githubusercontent.com/formcept/whiteboard/master/nbviewer/notebooks/data/harrypotter/Book%203%20-%20The%20Prisoner%20of%20Azkaban.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))

chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1


# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Using TensorFlow backend.
# corpus length: 676978
# total chars: 60
# nb sequences: 225646
# Vectorization...
# Build model...
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/60
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From D:\Anaconda\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 225646/225646 [==============================] - 237s 1ms/step - loss: 1.8679
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "ays he can’t risk it happenin’ again.”
# "
# ays he can’t risk it happenin’ again.”
#
# “no was
# think and his
# been had
# still the come the strain of his stared to have to have to
# the winding the corriously the starting the propessor the compage the proves of his
# pass of the
# propessor the case and the come to have be
# the coptanted to
# the wants of his
# better and the come of his
# the think to the trought on the come of the come of the wand the wand the come to had been to the
#
# ----- diversity: 0.5
# ----- Generating with seed: "ays he can’t risk it happenin’ again.”
# "
# ays he can’t risk it happenin’ again.”
#
# but harry was classent to the had from me class of here, and professor from and and harry.
#
#
#
# page | 266 harry potter and the prisoner of
# |||| harry potter a
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:57: RuntimeWarning: divide by zero encountered in log
# nd the prisoner of a||||| harry potter and the prisoner of||||||| hin and the professor
# rrang
# t|||||||| harry potter and the prisoner ||||||||| a
# ot on
#
#
#
#
#
# the pressed
# z|||||||||| harry fotter potter and th| ||||||||||| aonlithore and
# ----- diversity: 1.0
# ----- Generating with seed: "ays he can’t risk it happenin’ again.”
# "
# ays he can’t risk it happenin’ again.”
#
# he down entayin. tryinustly and
# memindors invior
# pottily belan
#  weaslens ground verins intuf, buckscoradly troush notch’s didestly
# downstalle,
# the
# never starnly. anoy, peres brow hoppupsudneass?” said voile. the case pagar. harry.”
#
# harry
# uppean on roughtaics it anto;ens; prifessor madent into
#
# then in igsone and hormiedn’t gry.”
#
# “you kifne, had ne!” he said this winnow to maghidating
# ----- diversity: 1.2
# ----- Generating with seed: "ays he can’t risk it happenin’ again.”
# "
# ays he can’t risk it happenin’ again.”
#
# dore sped,” said ron ... readigh, shirtcemally
# ushowelly, an, you vury plywing
# to love back theirs look pe pleend. harry classtant lusts. the spoitte. -nove dall on, hirdon, didelable who sleementted thl he’d brindly had speft magitch movers hossumus fulpre” crabmathere the cyrown, loof floved.”
#
# “noi fith unch it s.ory. in bad dettoly. nool tyoid las. breat were abmip1foriat mussessok. harry
# Epoch 2/60
# 225646/225646 [==============================] - 209s 927us/step - loss: 1.5107s - loss: 1
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "at very hard indeed.
#
# “come on, ron, yo"
# at very hard indeed.
#
# “come on, ron, you was staring and feeling to hear
# been the class and
# the black to her the closs of the start and the come of the didn’t
# seemed to a come of the clowed the clowed to hear
# the
# start of the
# started to the class to
# harry was
# was started a
# bold
# the clowed the door.
#
# “where in the stoom off them staring to
# hermione was
# staring the clowed the common a clowed to cand
# them and he came a clowe
# ----- diversity: 0.5
# ----- Generating with seed: "at very hard indeed.
#
# “come on, ron, yo"
# at very hard indeed.
#
# “come on, ron, you was staring it them —
#
# “where see’d as hermione had been the
# one of a comming, in the come to the
# bleaked to dead and didn’t
# seemed them down.
#
# harry was come them, and
#
# put of the staring didn’t house
# their let of them clooks and he’s shing to the come of them all three
# sance and didn’t get office, hermione and them all to the lown to when a
# real a
# wand harry had been
# the seech them
# ----- diversity: 1.0
# ----- Generating with seed: "at very hard indeed.
#
# “come on, ron, yo"
# at very hard indeed.
#
# “come on, ron, you under you aed him,
# stanns, a diddy pooted to sitefult worst creas and excemut, rungem had care down
# his wish. “i’d — you foenk a voiment. “infore. saren whints and hermione, and they were all
# off, but caremates’ing toward himself, like in h, gon,” said hermione.
# ron
# exrectorst the exembering to visided him, you letterhs and he’s cooking
# the leanie’s all awaymactd
# with his into them.
#
# pat
# ----- diversity: 1.2
# ----- Generating with seed: "at very hard indeed.
#
# “come on, ron, yo"
# at very hard indeed.
#
# “come on, ron, you you a’d feed nast.  as well had didn’t looked buchbed ene.” a hormicteate, was at-luffvy.”
#
# heardy surplinly live from on sigent. ...”
#
# to weraliny hall, while hadn’t
# new his as, wive have right’s chmed, clrad. tuth madryon on, — ” she wasing hermione was on.”
#
#
#
# fust
# assamed?” hexspelbed  for fisthbon led let into stapus!” headidily brand.” he looking snappinially hermione. snanuing toal c
# Epoch 3/60
# 225646/225646 [==============================] - 310s 1ms/step - loss: 1.4308
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "” said hermione in a terrified whisper. "
# ” said hermione in a terrified whisper.
#
# “i don’t have
# see of the find of
# him
# the way
# but they down the dight of his
# hands of the down and he said,
# he saw
# they was
# had form of the firebolt and
# harry and hermione said, “it’s they seemed to have to have to have have to have
# they
# can’t do they
# saw it.
#
# “you see of the common the leant
# the way the dear and
# here and
# hermione said, harry and hermione said and
# had the bed the
# ----- diversity: 0.5
# ----- Generating with seed: "” said hermione in a terrified whisper. "
# ” said hermione in a terrified whisper.
#
# “a concenter, had think of
# of their
# head from the trough of the dementors,
# harry had looking of suddenly and they
# can’t
# thought and here, i have slid what
# was armin’t from the day.
#
#
#
# they
# can’t hour
# on the traight of
# him the black and some of the field.
#
# “it’s they leave him see
# the patronuss, which was we looked and
# ron said his enwing
# harry and hermione said of the way.
#
# “armas
# ----- diversity: 1.0
# ----- Generating with seed: "” said hermione in a terrified whisper. "
# ” said hermione in a terrified whisper.
# “been downcames cat about uncle shully seend of dogs.
#
# your voice. “untiok extrat ally of roves they don’t their wore of heedver before ’em him, it’s dour weasley, looked.”
#
# “demoong aging. howevinf becont downts
# ’lon of the craiving of your ablaw the grait for
# snape and hands,
# buckberk
# as tank have hough him. ha; have to that, was plock werelels ron for a list.”
#
# “dow, wand,” said ron lav
# ----- diversity: 1.2
# ----- Generating with seed: "” said hermione in a terrified whisper. "
# ” said hermione in a terrified whisper. professor
# tromsling leps, rtudder be last
# lovelpese.
#
# “like front be the gace. hi inaysting the coumiate, it’s encamticar. “a walns, ig ry ver.”
#
# “year’s y asmedhatof coolas work — sorryfulate we’llon, mis, plaker, rair,” said
# thete feel plactervo
# mennaply. had warg wiver for
# prouedne — next two har’s told on dodric it
# was sriehing
# she was cheitch more long hereves mon’t — i now,” said sn
# Epoch 4/60
# 225646/225646 [==============================] - 274s 1ms/step - loss: 1.4053
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "d fudge, startled, “the young lady is
# d"
# d fudge, startled, “the young lady is
# down the started the
# count of the
# corridous
#
# page |  he harry pot the prisoner oroand her rest
# of the pralf oo —
#
# “what?” said harry had
# before harry saw the
# way
# the book and
# she was
# staring
# and weasley.
#
# “we was
# staring a class and he was
# staning
# the
# count of the
# corner the stand on the
# stan
# shoulder to the
# stopped and started to the
# stand and
# and
# stan she
# can the stan
# and
# ----- diversity: 0.5
# ----- Generating with seed: "d fudge, startled, “the young lady is
# d"
# d fudge, startled, “the young lady is
# did if a chock the count of the castle in the dark as the book
# and
# steps and head
# and was tell the firebolt’s hand
# the
# had been sirius
# something out of the prosione of see staning and the professor trelawney. “i was on the other of the
# stan and voice, he have offing
# check and was shouting the stant to his let the parrohisses and weasley and
# parsides
# castle before he were a bet and
# and hi
# ----- diversity: 1.0
# ----- Generating with seed: "d fudge, startled, “the young lady is
# d"
# d fudge, startled, “the young lady is
# dething the cavement of them them led
# a cho that begoner, sode thisted at the picked to tell the doorsteating the montant
# casty
# resten by oren.”
#
# ture un’e o cunder thebrokes topet
# sie unclens with at her will might-persed the speat. “harry’s ear 1— unbe just scarged. ... eter’s year. ithere escher, you faught u not me — blazkgled
# malfoy
# so, day. “nodd’in hor,” said lupin, the
# could have at
# ----- diversity: 1.2
# ----- Generating with seed: "d fudge, startled, “the young lady is
# d"
# d fudge, startled, “the young lady is
# depeen i retick.
#
# “they see that a flieveo fred much ou bee, sirius. malfcyou to i wettenwing hole of the con, — hat you’ve maded a
# golded hasts by byen,
# didinvice again. the defenits and wiped the shake. but thir fumbly gottsn’t botter, this cear mina; !” she recided the lit secrectway withtlish they
# moaked, fevererved soorifile of scoming by wega right teartosited.”
#
# he flap by the might. ea
# Epoch 5/60
# 225646/225646 [==============================] - 323s 1ms/step - loss: 1.4086 1s - l
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "et flags with the gryffindor lion
# upon "
# et flags with the gryffindor lion
# upon his stood of the
# will have to the
# watch and
# hermione
# she was
# should be
# are
# was staring the class of the
# staring a
# reach and
# head
# she was should
# be see
# his streading
# harry was staring the
# shoulder the
# watch and
# she was she was stood of his
# wand a
# coment the
# staring
# hermione
# was
# staring the
# should the
# staring at his
# stood and
# hermione
# watched the
# staring
# his
# better wat
# ----- diversity: 0.5
# ----- Generating with seed: "et flags with the gryffindor lion
# upon "
# et flags with the gryffindor lion
# upon of his hand which was sheard the
# all the
# could
# ed hand hand a a
# way of the class the three watching
# him ron and hermione of his wain and look and
# he was stooled out of the thing of the
# contangely and
# acriaged with the
# heard close thing was sign way as he was sudeeked at her wand harry was
# pattered a chocolate had for harry
# could have to have to
# have so all the staring
#
# grimbers was
# t
# ----- diversity: 1.0
# ----- Generating with seed: "et flags with the gryffindor lion
# upon "
# et flags with the gryffindor lion
# upon holding in ... you  encome could hear up downching — harry neconded fudge, shes the manninh othing while
# visius watch look over the nexply as her loogertated, way pound — profthmrgilily wandering it. there wolldand off the excioust
# chrolition notuint of a low noint to their
#
#
# staring — percy watched  aver, surve of still the temk cloaked himfort
# itwind — owl, giving he?” said hermione
# waid th
# ----- diversity: 1.2
# ----- Generating with seed: "et flags with the gryffindor lion
# upon "
# et flags with the gryffindor lion
# upon came runasts?  hangered flewt disiket dionling from thon waugholr. har threfain what watten
# worcer geaty mored hogsiet fach, but honuss by wake help dunning a thirded like the look wh james
# wrying to
# pare to daid, is talk all or anmill for the veistmass to
# mevillly srill, all
# in the tramments.
# the out
# cattle like it, them were harder by heard withver carlan hogesmels. he heard or murles. —
# Epoch 6/60
#  45824/225646 [=====>........................] - ETA: 4:13 - loss: 1.3506- ETA: 4:19 - loss
